# %% [markdown]
# # News Mood

# %% [markdown]
# - Each news sources has moderately negative sentiment at the time of analysis.
# - The most negative and most positive tweets occurred within the last 20 tweets.
# - It would seem that a majority of each news sources tweets' were graded with neutral compound sentiment (0).

# %%
consumer_key = "r1CGEJjGlrTmuUILfpJOYboYX"
consumer_secret = "PaAN0u5xUEB6FW59ZtQw9DHS95WWj1d9jzchbxXFVGQrGpvA4R"
access_token = "901933530258829312-y9BaHYc1jigRcWrWuGxcs0eYomJMY12"
access_token_secret = "KCSTd4QoPgiPwtYo0MSo185ACE2vPS5WLOrqnAd3xFsxx"

# %%
import tweepy
import json
import numpy as np
import pandas as pd
import seaborn
import matplotlib.pyplot as plt
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()
import time

# %%
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth, parser=tweepy.parsers.JSONParser())

# %%
tweet_df = pd.DataFrame(columns = ["Source Account", "Tweet Text", "Date", "Tweets Ago", "Compound Sentiment", "Positive Sentiment", "Neutral Sentiment", "Negative Sentiment"])

# %%
target_user = ["BBCNews", "CBSNews", "CNN", "FoxNews", "nytimes"]
indexcount = 0
comp_avg = []

# %%
for user in target_user:
    public_tweets = api.user_timeline(user, count=100)
    tweetnumber = 0
    comp_list = []
    for tweet in public_tweets:
        search = tweet["text"]
        tweetdate = tweet["created_at"]
        compoundsent = analyzer.polarity_scores(search)["compound"]
        comp_list.append(analyzer.polarity_scores(search)["compound"])
        positivesent = analyzer.polarity_scores(search)["pos"]
        neutralsent = analyzer.polarity_scores(search)["neu"]
        negativesent = analyzer.polarity_scores(search)["neg"]
        tweet_df.set_value(indexcount, "Source Account", user)
        tweet_df.set_value(indexcount, "Tweet Text", search)
        tweet_df.set_value(indexcount, "Date", tweetdate)
        tweet_df.set_value(indexcount, "Tweets Ago", tweetnumber)
        tweet_df.set_value(indexcount, "Compound Sentiment", compoundsent)            
        tweet_df.set_value(indexcount, "Positive Sentiment", positivesent)
        tweet_df.set_value(indexcount, "Neutral Sentiment", neutralsent)
        tweet_df.set_value(indexcount, "Negative Sentiment", negativesent)
        indexcount = indexcount + 1
        tweetnumber = tweetnumber + 1
    comp_avg.append(np.mean(comp_list))

# %%
comp_avg
# Out:
# [-0.14169799999999999,
#  -0.11824999999999999,
#  -0.135129,
#  -0.13838100000000003,
#  -0.13440000000000002]

# %%
tweet_df
# Out:
#     Source Account                                         Tweet Text  \
# 0          BBCNews  RT @BBCRoryCJ: Uber + TfL met at a secret loca...
# 1          BBCNews  RT @BBCNewsbeat: The government wants to give ...
# 2          BBCNews  Boris Johnson: Let the British lion roar https...
# 3          BBCNews  Tuition fee changes 'to save students £15,700'...
# 4          BBCNews  Landfill search for airman to restart https://...
# 5          BBCNews  "We are the party that believes in this countr...
# 6          BBCNews  RT @BBCBreaking: Police to resume search of la...
# 7          BBCNews  RT @BBCBreaking: US expels 15 Cuban diplomats,...
# 8          BBCNews  "It is time to be bold, to seize the opportuni...
# 9          BBCNews  "We must believe in global Britain" - @BorisJo...
# 10         BBCNews  RT @BBCSport: England players Eniola Aluko and...
# 11         BBCNews  Follow the latest news from #CPC17 in Manchest...
# 12         BBCNews  Scottish government backs ban on fracking http...
# 13         BBCNews  RT @BBCNormanS: David Davis accuses unnamed EU...
# 14         BBCNews  UK aiming for "a good deal" on #Brexit but is ...
# 15         BBCNews  Stourbridge stabbing: Aaron Barley admits murd...
# 16         BBCNews  Jenna Miller 'killed by drivers in 70mph race'...
# 17         BBCNews  RT @ChrisMasonBBC: Pensions campaigners outsid...
# 18         BBCNews  RT @BBCScotlandNews: The UK government has for...
# 19         BBCNews  RT @BBCNormanS: Universal Credit heading towar...
# 20         BBCNews  RT @BBCNormanS: Liam Fox says BBC coverage "tr...
# 21         BBCNews  Conservative fears of a downward spiral — blog...
# 22         BBCNews  RT @BBCEngland: An imam accused of making Isla...
# 23         BBCNews  Rodney Bickerstaffe, ex-Unision general secret...
# 24         BBCNews  Teenager charged after Ellon Academy incident ...
# 25         BBCNews  RT @daily_politics: Jacob Rees-Mogg confronted...
# 26         BBCNews  RT @DannyShawBBC: More on acid: Sulphuric acid...
# 27         BBCNews  RT @BBCBreaking: Sale of acids to people aged ...
# 28         BBCNews  Sale of acids to under-18s to be banned https:...
# 29         BBCNews  Former women's college fields all-male Univers...
# ..             ...                                                ...
# 470        nytimes  Tech companies should act decisively to preven...
# 471        nytimes  RT @nytimesmusic: CBS erroneously reports Tom ...
# 472        nytimes  Ariana Grande, whose concert was struck by a s...
# 473        nytimes  RT @nytopinion: A Congressman thought his coll...
# 474        nytimes  GM plans at least 20 all-electric vehicles by ...
# 475        nytimes  “I’ve been a nurse for 30 years, and this was ...
# 476        nytimes  A musician who was at the Las Vegas festival s...
# 477        nytimes  RT @UpshotNYT: Another look at what might work...
# 478        nytimes  Equifax believes up to 145.5 million people ma...
# 479        nytimes  Last year, her husband forgot their anniversar...
# 480        nytimes  In Gaza, a reconciliation may be happening bet...
# 481        nytimes  Fact Check: Viral claims and rumors in the Las...
# 482        nytimes  One NYT reader's reaction to the mass shooting...
# 483        nytimes  Incomplete records of Puerto Rico's landscape ...
# 484        nytimes  RT @palafo: When they heard the shooting, Sonn...
# 485        nytimes  After defying the Madrid government, separatis...
# 486        nytimes  RT @nytopinion: Let’s mourn. But even more imp...
# 487        nytimes  One NYT reader's reaction to the mass shooting...
# 488        nytimes  Watch the controlled explosion that brought do...
# 489        nytimes  What makes Singapore's health care so cheap? h...
# 490        nytimes  The duration of the bursts in Las Vegas sugges...
# 491        nytimes  The Las Vegas gunman had 19 rifles in his hote...
# 492        nytimes  Oct. 1, 2017\nJuly 7, 2016\nJune 12, 2016\nDec...
# 493        nytimes  Some blood donors in Las Vegas were in line as...
# 494        nytimes  "This world is sick." Musicians from the Las V...
# 495        nytimes  Thousands of young undocumented immigrants are...
# 496        nytimes  “No one has experienced patient volumes to thi...
# 497        nytimes  Opinion: "Let’s mourn. But even more important...
# 498        nytimes  Eric Paddock, the Las Vegas suspect’s brother,...
# 499        nytimes  Caleb Keeter of Josh Abbott Band said that the...
#
#                                Date Tweets Ago Compound Sentiment  \
# 0    Tue Oct 03 16:08:03 +0000 2017          0             0.4877
# 1    Tue Oct 03 15:59:02 +0000 2017          1            -0.2023
# 2    Tue Oct 03 15:51:06 +0000 2017          2                  0
# 3    Tue Oct 03 15:21:53 +0000 2017          3             0.4939
# 4    Tue Oct 03 15:21:50 +0000 2017          4                  0
# 5    Tue Oct 03 15:20:41 +0000 2017          5             0.4019
# 6    Tue Oct 03 15:19:50 +0000 2017          6             -0.296
# 7    Tue Oct 03 15:19:45 +0000 2017          7            -0.7351
# 8    Tue Oct 03 15:05:25 +0000 2017          8             0.6369
# 9    Tue Oct 03 14:53:35 +0000 2017          9                  0
# 10   Tue Oct 03 14:21:11 +0000 2017         10                  0
# 11   Tue Oct 03 13:46:32 +0000 2017         11                  0
# 12   Tue Oct 03 13:40:23 +0000 2017         12            -0.5859
# 13   Tue Oct 03 13:39:05 +0000 2017         13            -0.6597
# 14   Tue Oct 03 13:38:59 +0000 2017         14             0.6369
# 15   Tue Oct 03 13:25:05 +0000 2017         15            -0.5423
# 16   Tue Oct 03 13:25:04 +0000 2017         16            -0.6705
# 17   Tue Oct 03 13:00:59 +0000 2017         17                  0
# 18   Tue Oct 03 12:45:14 +0000 2017         18                  0
# 19   Tue Oct 03 12:45:05 +0000 2017         19            -0.4404
# 20   Tue Oct 03 12:28:42 +0000 2017         20             -0.296
# 21   Tue Oct 03 12:22:48 +0000 2017         21            -0.4215
# 22   Tue Oct 03 12:15:19 +0000 2017         22             -0.296
# 23   Tue Oct 03 12:04:58 +0000 2017         23                  0
# 24   Tue Oct 03 12:04:55 +0000 2017         24            -0.2023
# 25   Tue Oct 03 12:04:00 +0000 2017         25            -0.2023
# 26   Tue Oct 03 11:59:41 +0000 2017         26            -0.4588
# 27   Tue Oct 03 11:39:36 +0000 2017         27            -0.4588
# 28   Tue Oct 03 11:38:28 +0000 2017         28            -0.4588
# 29   Tue Oct 03 11:36:10 +0000 2017         29             0.0772
# ..                              ...        ...                ...
# 470  Tue Oct 03 00:47:03 +0000 2017         70             -0.296
# 471  Tue Oct 03 00:32:02 +0000 2017         71            -0.5994
# 472  Tue Oct 03 00:17:04 +0000 2017         72             -0.836
# 473  Tue Oct 03 00:02:06 +0000 2017         73            -0.6597
# 474  Mon Oct 02 23:47:02 +0000 2017         74                  0
# 475  Mon Oct 02 23:32:03 +0000 2017         75            -0.8481
# 476  Mon Oct 02 23:17:05 +0000 2017         76             0.2023
# 477  Mon Oct 02 23:02:06 +0000 2017         77            -0.3182
# 478  Mon Oct 02 22:47:06 +0000 2017         78            -0.4939
# 479  Mon Oct 02 22:32:04 +0000 2017         79                  0
# 480  Mon Oct 02 22:18:05 +0000 2017         80                  0
# 481  Mon Oct 02 22:07:05 +0000 2017         81                  0
# 482  Mon Oct 02 21:55:56 +0000 2017         82                  0
# 483  Mon Oct 02 21:41:30 +0000 2017         83            -0.1027
# 484  Mon Oct 02 21:32:04 +0000 2017         84             0.4939
# 485  Mon Oct 02 21:15:07 +0000 2017         85                  0
# 486  Mon Oct 02 20:56:05 +0000 2017         86            -0.1796
# 487  Mon Oct 02 20:46:04 +0000 2017         87                  0
# 488  Mon Oct 02 20:35:05 +0000 2017         88                  0
# 489  Mon Oct 02 20:25:02 +0000 2017         89             0.4939
# 490  Mon Oct 02 20:15:13 +0000 2017         90            -0.4404
# 491  Mon Oct 02 20:08:35 +0000 2017         91                  0
# 492  Mon Oct 02 20:05:06 +0000 2017         92                  0
# 493  Mon Oct 02 19:55:04 +0000 2017         93                  0
# 494  Mon Oct 02 19:45:07 +0000 2017         94            -0.6705
# 495  Mon Oct 02 19:35:07 +0000 2017         95                  0
# 496  Mon Oct 02 19:25:07 +0000 2017         96                  0
# 497  Mon Oct 02 19:15:10 +0000 2017         97            -0.1796
# 498  Mon Oct 02 19:05:08 +0000 2017         98            -0.0516
# 499  Mon Oct 02 18:55:03 +0000 2017         99              -0.34
#
#     Positive Sentiment Neutral Sentiment Negative Sentiment
# 0                0.143             0.857                  0
# 1                    0             0.924              0.076
# 2                    0                 1                  0
# 3                0.314             0.686                  0
# 4                    0                 1                  0
# 5                0.184             0.816                  0
# 6                    0             0.879              0.121
# 7                0.088             0.612              0.299
# 8                0.286             0.714                  0
# 9                    0                 1                  0
# 10                   0                 1                  0
# 11                   0                 1                  0
# 12                   0              0.51               0.49
# 13                   0             0.707              0.293
# 14               0.224             0.776                  0
# 15               0.185              0.42              0.395
# 16                   0              0.69               0.31
# 17                   0                 1                  0
# 18                   0                 1                  0
# 19               0.118             0.633              0.249
# 20                   0             0.833              0.167
# 21                   0             0.763              0.237
# 22                   0             0.896              0.104
# 23                   0                 1                  0
# 24                   0             0.769              0.231
# 25                   0             0.899              0.101
# 26                   0              0.87               0.13
# 27                   0              0.87               0.13
# 28                   0             0.727              0.273
# 29                0.14              0.86                  0
# ..                 ...               ...                ...
# 470              0.067             0.793               0.14
# 471                  0             0.769              0.231
# 472                  0             0.656              0.344
# 473                  0             0.812              0.188
# 474                  0                 1                  0
# 475                  0             0.687              0.313
# 476              0.142             0.752              0.106
# 477              0.076             0.759              0.166
# 478                  0             0.856              0.144
# 479                  0                 1                  0
# 480                  0                 1                  0
# 481                  0                 1                  0
# 482                  0                 1                  0
# 483                  0             0.931              0.069
# 484              0.132             0.868                  0
# 485                  0                 1                  0
# 486              0.132             0.692              0.176
# 487                  0                 1                  0
# 488                  0                 1                  0
# 489              0.314             0.686                  0
# 490                  0             0.879              0.121
# 491                  0                 1                  0
# 492                  0                 1                  0
# 493                  0                 1                  0
# 494                  0             0.791              0.209
# 495                  0                 1                  0
# 496                  0                 1                  0
# 497              0.162              0.62              0.217
# 498              0.097             0.796              0.106
# 499                  0             0.902              0.098
#
# [500 rows x 8 columns]

# %%
#export to csv for final file

# %%
x_axis = (100, 0, 1)
bbcplot = plt.scatter(tweet_df[tweet_df["Source Account"] == "BBCNews"]["Tweets Ago"], tweet_df[tweet_df["Source Account"] == "BBCNews"]["Compound Sentiment"], marker="o", c="turquoise", edgecolors="black", linewidth=1 ,s=125, alpha=1, label="BBC")
cbsplot = plt.scatter(tweet_df[tweet_df["Source Account"] == "CBSNews"]["Tweets Ago"], tweet_df[tweet_df["Source Account"] == "CBSNews"]["Compound Sentiment"], marker="o", facecolors="green", edgecolors="black", linewidth=1, s=125, alpha=1, label="CBS")
cnnplot = plt.scatter(tweet_df[tweet_df["Source Account"] == "CNN"]["Tweets Ago"], tweet_df[tweet_df["Source Account"] == "CNN"]["Compound Sentiment"], marker="o", facecolors="red", edgecolors="black", linewidth=1,s=125, alpha=1, label="CNN")
foxplot = plt.scatter(tweet_df[tweet_df["Source Account"] == "FoxNews"]["Tweets Ago"], tweet_df[tweet_df["Source Account"] == "FoxNews"]["Compound Sentiment"], marker="o", facecolors="blue", edgecolors="black", linewidth=1,s=125, alpha=1, label="Fox")
nytplot = plt.scatter(tweet_df[tweet_df["Source Account"] == "nytimes"]["Tweets Ago"], tweet_df[tweet_df["Source Account"] == "nytimes"]["Compound Sentiment"], marker="o", facecolors="yellow", edgecolors="black", linewidth=1,s=125, alpha=1, label="New York Times")
leg = plt.legend(title="Media Sources",fontsize=12, bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.setp(leg.get_title(),fontsize=14)
bbox_inches="tight"
plt.title("Sentiment Analysis of Media Tweets " + str(time.strftime("%x")), fontsize=16)
plt.xlabel("Tweets Ago", fontsize=14)
plt.ylabel("Tweet Polarity", fontsize=14)
plt.ylim(-1.1, 1.1)
plt.xlim(105, -5)
plt.show()

# %%
#tweet_df.groupby('Source Account')["Compound Sentiment"].mean()
tweet_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 500 entries, 0 to 499
# Data columns (total 8 columns):
# Source Account        500 non-null object
# Tweet Text            500 non-null object
# Date                  500 non-null object
# Tweets Ago            500 non-null object
# Compound Sentiment    500 non-null object
# Positive Sentiment    500 non-null object
# Neutral Sentiment     500 non-null object
# Negative Sentiment    500 non-null object
# dtypes: object(8)
# memory usage: 55.2+ KB

# %%
plt.figure(figsize=(10,7))
x_axis2 = np.arange(len(target_user))

rect1 = plt.bar(0, comp_avg[0], color='turquoise', alpha=1, align="edge", ec="black", width=1)
rect2 = plt.bar(1, comp_avg[1], color='green', alpha=1, align="edge", ec="black", width=1)
rect3 = plt.bar(2, comp_avg[2], color='red', alpha=1, align="edge", ec="black", width=1)
rect4 = plt.bar(3, comp_avg[3], color='blue', alpha=1, align="edge", ec="black", width=1)
rect5 = plt.bar(4, comp_avg[4], color='yellow', alpha=1, align="edge", ec="black", width=1)

tick_locations = [value+0.5 for value in x_axis2]
plt.grid(linestyle="dashed")
plt.xticks(tick_locations, target_user)
plt.xlim(0, 5)
plt.ylim(-.2, .05)
# Out:
# (-0.2, 0.05)

# %%
plt.title("Overall Media Sentiment Based on Twitter " + str(time.strftime("%x")), fontsize=20)
plt.ylabel("Tweet Polarity")

# %%
def label_negative(rects):
    for rect in rects:
        height = rect.get_height()
        plt.text(rect.get_x() + rect.get_width()/2., (height)-0.01,
                '-%.2f' % float(height),
                ha='center', va='bottom')


label_negative(rect1)
label_negative(rect2)
label_negative(rect3)
label_negative(rect4)
label_negative(rect5)

# %%
plt.show()
